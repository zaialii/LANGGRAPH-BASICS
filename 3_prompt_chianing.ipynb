# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

# model = ChatOpenAI()
# Out:
# False

# %%
class BlogState(TypedDict):
    title : str
    outline : str
    content : str

# %%
# define functins

def create_outline(state: BlogState) -> BlogState

# fetch title

title = state['title']

# call llm gen outline

prompt = f"Generate the detailed outline for a blog on the topic - {title}"
outline = model.invoke(prompt).content

# udpate state

state['outline'] = outline

return state

# %%
# define function

def create_blog(state: BlogState) -> BlogState:
    
    title = state['title']
    outline = state['outline']
    
    prompt = f'Write a detailed blog on a title - {title} using the following outline \n {outline} '
    content = model.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

#node
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# add egdes

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 graph = StateGraph(BlogState)
#       3 #node
# ----> 4 graph.add_node('create_outline', create_outline)
#       5 graph.add_node('create_blog', create_blog)
#       7 # add egdes
#
# NameError: name 'create_outline' is not defined

# %%
initial_state = {'title' : 'Rise of AI in Pakistan'}

final_state = workflow.invoke(initial_state)

return state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 initial_state = {'title' : 'Rise of AI in Pakistan'}
# ----> 3 final_state = workflow.invoke(initial_state)
#       5 return state
#
# NameError: name 'workflow' is not defined

# %%
print(final_state['outline'])

# %%
print(final_state['content'])
